# %% [markdown]
# >" A valid SIP request formulated by a UAC MUST, at a minimum, contain
# the following header fields: To, From, CSeq, Call-ID, Max-Forwards,
# and Via; all of these header fields are mandatory in all SIP
# requests."

# %% [markdown]
# # Linphone -> Linphone

# %% [markdown]
# ```
# INVITE sip:charl@100.70.82.70 SIP/2.0
# Via: SIP/2.0/UDP 100.124.130.10:5060;branch=z9hG4bK.Wn9x8WZtw;rport
# From: "Ext 1" <sip:12034946640@10.136.203.238>;tag=0maA2k1zf
# To: sip:charl@100.70.82.70
# CSeq: 20 INVITE
# Call-ID: uB~qNuhjbg
# Max-Forwards: 70
# Supported: replaces, outbound, gruu, path, record-aware
# Allow: INVITE, ACK, CANCEL, OPTIONS, BYE, REFER, NOTIFY, MESSAGE, SUBSCRIBE, INFO, PRACK, UPDATE
# Content-Type: application/sdp
# Content-Length: 543
# Contact: <sip:100.124.130.10;transport=udp>;+org.linphone.specs="lime"
# User-Agent: Linphone-Desktop/5.2.6 (MCgo) osx/15.2 Qt/5.15.2 LinphoneSDK/5.3.72
#
# v=0
# o=12034946640 3723 1493 IN IP4 100.124.130.10
# s=Talk
# c=IN IP4 100.124.130.10
# t=0 0
# a=rtcp-xr:rcvr-rtt=all:10000 stat-summary=loss,dup,jitt,TTL voip-metrics
# a=record:off
# m=audio 7078 RTP/AVP 96 97 98 0 8 18 101 99 100
# a=rtpmap:96 opus/48000/2
# a=fmtp:96 useinbandfec=1
# a=rtpmap:97 speex/16000
# a=fmtp:97 vbr=on
# a=rtpmap:98 speex/8000
# a=fmtp:98 vbr=on
# a=fmtp:18 annexb=yes
# a=rtpmap:101 telephone-event/48000
# a=rtpmap:99 telephone-event/16000
# a=rtpmap:100 telephone-event/8000
# a=rtcp-fb:* trr-int 5000
# a=rtcp-fb:* ccm tmmbr
#
# SIP/2.0 100 Trying
# Via: SIP/2.0/UDP 100.124.130.10:5060;branch=z9hG4bK.Wn9x8WZtw;rport
# From: "Ext 1" <sip:12034946640@10.136.203.238>;tag=0maA2k1zf
# To: sip:charl@100.70.82.70
# Call-ID: uB~qNuhjbg
# CSeq: 20 INVITE
#
# SIP/2.0 180 Ringing
# Via: SIP/2.0/UDP 100.124.130.10:5060;branch=z9hG4bK.Wn9x8WZtw;rport
# From: "Ext 1" <sip:12034946640@10.136.203.238>;tag=0maA2k1zf
# To: <sip:charl@100.70.82.70>;tag=d329sRB
# Call-ID: uB~qNuhjbg
# CSeq: 20 INVITE
# User-Agent: Linphone-Desktop/5.2.6 (GigaTop) windows/10 Qt/5.15.2 LinphoneSDK/5.3.72
# Supported: replaces, outbound, gruu, path, record-aware
#
# SIP/2.0 200 Ok
# Via: SIP/2.0/UDP 100.124.130.10:5060;branch=z9hG4bK.Wn9x8WZtw;rport
# From: "Ext 1" <sip:12034946640@10.136.203.238>;tag=0maA2k1zf
# To: <sip:charl@100.70.82.70>;tag=d329sRB
# Call-ID: uB~qNuhjbg
# CSeq: 20 INVITE
# User-Agent: Linphone-Desktop/5.2.6 (GigaTop) windows/10 Qt/5.15.2 LinphoneSDK/5.3.72
# Supported: replaces, outbound, gruu, path, record-aware
# Allow: INVITE, ACK, CANCEL, OPTIONS, BYE, REFER, NOTIFY, MESSAGE, SUBSCRIBE, INFO, PRACK, UPDATE
# Contact: <sip:100.70.82.70;transport=udp>
# Content-Type: application/sdp
# Content-Length: 533
#
# v=0
# o=4003 3865 3246 IN IP4 100.70.82.70
# s=Talk
# c=IN IP4 100.70.82.70
# t=0 0
# a=rtcp-xr:rcvr-rtt=all:10000 stat-summary=loss,dup,jitt,TTL voip-metrics
# a=record:off
# m=audio 52022 RTP/AVP 96 97 98 0 8 18 101 99 100
# a=rtpmap:96 opus/48000/2
# a=fmtp:96 useinbandfec=1
# a=rtpmap:97 speex/16000
# a=fmtp:97 vbr=on
# a=rtpmap:98 speex/8000
# a=fmtp:98 vbr=on
# a=fmtp:18 annexb=yes
# a=rtpmap:101 telephone-event/48000
# a=rtpmap:99 telephone-event/16000
# a=rtpmap:100 telephone-event/8000
# a=rtcp-fb:* trr-int 5000
# a=rtcp-fb:* ccm tmmbr
#
# ACK sip:100.70.82.70;transport=udp SIP/2.0
# Via: SIP/2.0/UDP 100.124.130.10:5060;rport;branch=z9hG4bK.L8LupF4NN
# From: "Ext 1" <sip:12034946640@10.136.203.238>;tag=0maA2k1zf
# To: <sip:charl@100.70.82.70>;tag=d329sRB
# CSeq: 20 ACK
# Call-ID: uB~qNuhjbg
# Max-Forwards: 70
# User-Agent: Linphone-Desktop/5.2.6 (MCgo) osx/15.2 Qt/5.15.2 LinphoneSDK/5.3.72
#
#
# BYE sip:100.124.130.10;transport=udp SIP/2.0
# Via: SIP/2.0/UDP 100.70.82.70:5060;branch=z9hG4bK.zCfG21y19;rport
# From: <sip:charl@100.70.82.70>;tag=d329sRB
# To: "Ext 1" <sip:12034946640@10.136.203.238>;tag=0maA2k1zf
# CSeq: 111 BYE
# Call-ID: uB~qNuhjbg
# Max-Forwards: 70
# User-Agent: Linphone-Desktop/5.2.6 (GigaTop) windows/10 Qt/5.15.2 LinphoneSDK/5.3.72
#
#
# SIP/2.0 200 Ok
# Via: SIP/2.0/UDP 100.70.82.70:5060;branch=z9hG4bK.zCfG21y19;rport
# From: <sip:charl@100.70.82.70>;tag=d329sRB
# To: "Ext 1" <sip:12034946640@10.136.203.238>;tag=0maA2k1zf
# Call-ID: uB~qNuhjbg
# CSeq: 111 BYE
# User-Agent: Linphone-Desktop/5.2.6 (MCgo) osx/15.2 Qt/5.15.2 LinphoneSDK/5.3.72
# Supported: replaces, outbound, gruu, path, record-aware
#
# ```

# %% [markdown]
# # MicroSIP -> Linphone (Accept)

# %% [markdown]
# ```
# INVITE sip:0@100.124.130.10 SIP/2.0
# Via: SIP/2.0/UDP 100.70.82.70:56067;rport;branch=z9hG4bKPjeae2e75874bb4468891f9cab325d44b9
# Max-Forwards: 70
# From: "1011" <sip:hello@100.124.130.10>;tag=e11030a14be44441a1dc8d5647b612da
# To: <sip:0@100.124.130.10>
# Contact: "1011" <sip:hello@100.70.82.70:56067;ob>
# Call-ID: b7319c5f2ca74cd8b185195d96553d1f
# CSeq: 8544 INVITE
# Allow: PRACK, INVITE, ACK, BYE, CANCEL, UPDATE, INFO, SUBSCRIBE, NOTIFY, REFER, MESSAGE, OPTIONS
# Supported: replaces, 100rel, timer, norefersub
# Session-Expires: 1800
# Min-SE: 90
# User-Agent: MicroSIP/3.21.6
# Content-Type: application/sdp
# Content-Length:   345
#
# v=0
# o=- 3954689155 3954689155 IN IP4 10.136.106.147
# s=pjmedia
# b=AS:84
# t=0 0
# a=X-nat:0
# m=audio 4004 RTP/AVP 8 0 101
# c=IN IP4 10.136.106.147
# b=TIAS:64000
# a=rtcp:4005 IN IP4 10.136.106.147
# a=sendrecv
# a=rtpmap:8 PCMA/8000
# a=rtpmap:0 PCMU/8000
# a=rtpmap:101 telephone-event/8000
# a=fmtp:101 0-16
# a=ssrc:758253814 cname:0d7c250802cd3930
#
# SIP/2.0 100 Trying
# Via: SIP/2.0/UDP 100.70.82.70:56067;rport;branch=z9hG4bKPjeae2e75874bb4468891f9cab325d44b9
# From: "1011" <sip:hello@100.124.130.10>;tag=e11030a14be44441a1dc8d5647b612da
# To: sip:0@100.124.130.10
# Call-ID: b7319c5f2ca74cd8b185195d96553d1f
# CSeq: 8544 INVITE
#
# SIP/2.0 180 Ringing
# Via: SIP/2.0/UDP 100.70.82.70:56067;rport;branch=z9hG4bKPjeae2e75874bb4468891f9cab325d44b9
# From: "1011" <sip:hello@100.124.130.10>;tag=e11030a14be44441a1dc8d5647b612da
# To: <sip:0@100.124.130.10>;tag=z68gmdk
# Call-ID: b7319c5f2ca74cd8b185195d96553d1f
# CSeq: 8544 INVITE
# User-Agent: Linphone-Desktop/5.2.6 (MCgo) osx/15.2 Qt/5.15.2 LinphoneSDK/5.3.72
# Supported: replaces, outbound, gruu, path, record-aware
#
# SIP/2.0 200 Ok
# Via: SIP/2.0/UDP 100.70.82.70:56067;rport;branch=z9hG4bKPjeae2e75874bb4468891f9cab325d44b9
# From: "1011" <sip:hello@100.124.130.10>;tag=e11030a14be44441a1dc8d5647b612da
# To: <sip:0@100.124.130.10>;tag=z68gmdk
# Call-ID: b7319c5f2ca74cd8b185195d96553d1f
# CSeq: 8544 INVITE
# User-Agent: Linphone-Desktop/5.2.6 (MCgo) osx/15.2 Qt/5.15.2 LinphoneSDK/5.3.72
# Supported: replaces, outbound, gruu, path, record-aware
# Allow: INVITE, ACK, CANCEL, OPTIONS, BYE, REFER, NOTIFY, MESSAGE, SUBSCRIBE, INFO, PRACK, UPDATE
# Contact: <sip:100.124.130.10;transport=udp>;+org.linphone.specs="lime"
# Content-Type: application/sdp
# Content-Length: 156
#
# v=0
# o=12034946640 1487 553 IN IP4 10.136.203.238
# s=Talk
# c=IN IP4 10.136.203.238
# t=0 0
# m=audio 7078 RTP/AVP 8 0 101
# a=rtpmap:101 telephone-event/8000
#
# ACK sip:100.124.130.10;transport=udp SIP/2.0
# Via: SIP/2.0/UDP 100.70.82.70:56067;rport;branch=z9hG4bKPj6a879fa9dacd431781e47b322f90de5a
# Max-Forwards: 70
# From: "1011" <sip:hello@100.124.130.10>;tag=e11030a14be44441a1dc8d5647b612da
# To: <sip:0@100.124.130.10>;tag=z68gmdk
# Call-ID: b7319c5f2ca74cd8b185195d96553d1f
# CSeq: 8544 ACK
# Content-Length:  0
#
# UPDATE sip:100.124.130.10;transport=udp SIP/2.0
# Via: SIP/2.0/UDP 100.70.82.70:56067;rport;branch=z9hG4bKPja59bdf53c784449c9b1cc71a596bf694
# Max-Forwards: 70
# From: "1011" <sip:hello@100.124.130.10>;tag=e11030a14be44441a1dc8d5647b612da
# To: <sip:0@100.124.130.10>;tag=z68gmdk
# Contact: "1011" <sip:hello@100.70.82.70:56067;ob>
# Call-ID: b7319c5f2ca74cd8b185195d96553d1f
# CSeq: 8545 UPDATE
# Supported: replaces, 100rel, timer, norefersub
# Session-Expires: 1800
# Min-SE: 90
# Content-Type: application/sdp
# Content-Length:   321
#
# v=0
# o=- 3954689155 3954689156 IN IP4 10.136.106.147
# s=pjmedia
# b=AS:84
# t=0 0
# a=X-nat:0
# m=audio 4004 RTP/AVP 8 101
# c=IN IP4 10.136.106.147
# b=TIAS:64000
# a=rtcp:4005 IN IP4 10.136.106.147
# a=ssrc:758253814 cname:0d7c250802cd3930
# a=rtpmap:8 PCMA/8000
# a=rtpmap:101 telephone-event/8000
# a=fmtp:101 0-16
# a=sendrecv
#
# SIP/2.0 200 Ok
# Via: SIP/2.0/UDP 100.70.82.70:56067;rport;branch=z9hG4bKPja59bdf53c784449c9b1cc71a596bf694
# From: "1011" <sip:hello@100.124.130.10>;tag=e11030a14be44441a1dc8d5647b612da
# To: <sip:0@100.124.130.10>;tag=z68gmdk
# Call-ID: b7319c5f2ca74cd8b185195d96553d1f
# CSeq: 8545 UPDATE
# User-Agent: Linphone-Desktop/5.2.6 (MCgo) osx/15.2 Qt/5.15.2 LinphoneSDK/5.3.72
# Supported: replaces, outbound, gruu, path, record-aware
# Allow: INVITE, ACK, CANCEL, OPTIONS, BYE, REFER, NOTIFY, MESSAGE, SUBSCRIBE, INFO, PRACK, UPDATE
# Contact: <sip:100.124.130.10;transport=udp>;+org.linphone.specs="lime"
# Content-Type: application/sdp
# Content-Length: 154
#
# v=0
# o=12034946640 1487 555 IN IP4 10.136.203.238
# s=Talk
# c=IN IP4 10.136.203.238
# t=0 0
# m=audio 7078 RTP/AVP 8 101
# a=rtpmap:101 telephone-event/8000
# BYE sip:hello@100.70.82.70:56067;ob SIP/2.0
# Via: SIP/2.0/UDP 100.124.130.10:5060;branch=z9hG4bK.HiT3WTNeE;rport
# From: <sip:0@100.124.130.10>;tag=z68gmdk
# To: "1011" <sip:hello@100.124.130.10>;tag=e11030a14be44441a1dc8d5647b612da
# CSeq: 111 BYE
# Call-ID: b7319c5f2ca74cd8b185195d96553d1f
# Max-Forwards: 70
# User-Agent: Linphone-Desktop/5.2.6 (MCgo) osx/15.2 Qt/5.15.2 LinphoneSDK/5.3.72
#
#
# SIP/2.0 200 OK
# Via: SIP/2.0/UDP 100.124.130.10:5060;rport=5060;received=100.124.130.10;branch=z9hG4bK.HiT3WTNeE
# Call-ID: b7319c5f2ca74cd8b185195d96553d1f
# From: <sip:0@100.124.130.10>;tag=z68gmdk
# To: "1011" <sip:hello@100.124.130.10>;tag=e11030a14be44441a1dc8d5647b612da
# CSeq: 111 BYE
# Content-Length:  0
#
# ```

# %% [markdown]
# # Linphone -> Linphone (Decline)

# %% [markdown]
# ```
# INVITE sip:hello@100.105.32.112 SIP/2.0
# Via: SIP/2.0/UDP 100.124.130.10:5060;branch=z9hG4bK.dOufr3bTY;rport
# From: "Ext 1" <sip:12034946640@10.136.45.23>;tag=qebtLfwfI
# To: sip:hello@100.105.32.112
# CSeq: 20 INVITE
# Call-ID: tKHV8mp2ky
# Max-Forwards: 70
# Supported: replaces, outbound, gruu, path, record-aware
# Allow: INVITE, ACK, CANCEL, OPTIONS, BYE, REFER, NOTIFY, MESSAGE, SUBSCRIBE, INFO, PRACK, UPDATE
# Content-Type: application/sdp
# Content-Length: 543
# Contact: <sip:100.124.130.10;transport=udp>;+org.linphone.specs="lime"
# User-Agent: Linphone-Desktop/5.2.6 (MCgo) osx/15.2 Qt/5.15.2 LinphoneSDK/5.3.72
#
# v=0
# o=12034946640 3839 1478 IN IP4 100.124.130.10
# s=Talk
# c=IN IP4 100.124.130.10
# t=0 0
# a=rtcp-xr:rcvr-rtt=all:10000 stat-summary=loss,dup,jitt,TTL voip-metrics
# a=record:off
# m=audio 7078 RTP/AVP 96 97 98 0 8 18 101 99 100
# a=rtpmap:96 opus/48000/2
# a=fmtp:96 useinbandfec=1
# a=rtpmap:97 speex/16000
# a=fmtp:97 vbr=on
# a=rtpmap:98 speex/8000
# a=fmtp:98 vbr=on
# a=fmtp:18 annexb=yes
# a=rtpmap:101 telephone-event/48000
# a=rtpmap:99 telephone-event/16000
# a=rtpmap:100 telephone-event/8000
# a=rtcp-fb:* trr-int 5000
# a=rtcp-fb:* ccm tmmbr
#
# SIP/2.0 100 Trying
# Via: SIP/2.0/UDP 100.124.130.10:5060;branch=z9hG4bK.dOufr3bTY;rport
# From: "Ext 1" <sip:12034946640@10.136.45.23>;tag=qebtLfwfI
# To: sip:hello@100.105.32.112
# Call-ID: tKHV8mp2ky
# CSeq: 20 INVITE
#
# SIP/2.0 180 Ringing
# Via: SIP/2.0/UDP 100.124.130.10:5060;branch=z9hG4bK.dOufr3bTY;rport
# From: "Ext 1" <sip:12034946640@10.136.45.23>;tag=qebtLfwfI
# To: <sip:hello@100.105.32.112>;tag=A0ymf05
# Call-ID: tKHV8mp2ky
# CSeq: 20 INVITE
# User-Agent: LinphoneiOS/5.2.6 (iPhone) LinphoneSDK/5.3.106
# Supported: replaces, outbound, gruu, path, record-aware
#
# SIP/2.0 603 Decline
# Via: SIP/2.0/UDP 100.124.130.10:5060;branch=z9hG4bK.dOufr3bTY;rport
# From: "Ext 1" <sip:12034946640@10.136.45.23>;tag=qebtLfwfI
# To: <sip:hello@100.105.32.112>;tag=A0ymf05
# Call-ID: tKHV8mp2ky
# CSeq: 20 INVITE
# User-Agent: LinphoneiOS/5.2.6 (iPhone) LinphoneSDK/5.3.106
# Supported: replaces, outbound, gruu, path, record-aware
#
#
# ACK sip:hello@100.105.32.112 SIP/2.0
# Via: SIP/2.0/UDP 100.124.130.10:5060;branch=z9hG4bK.dOufr3bTY;rport
# Call-ID: tKHV8mp2ky
# From: "Ext 1" <sip:12034946640@10.136.45.23>;tag=qebtLfwfI
# To: <sip:hello@100.105.32.112>;tag=A0ymf05
# Contact: <sip:100.124.130.10;transport=udp>;+org.linphone.specs="lime"
# Max-Forwards: 70
# CSeq: 20 ACK
#
# ```
